# %%
import pandas as pd
#from SPARQLWrapper import SPARQLWrapper, JSON
#import ipython_sparql
from rdflib import Graph
from SPARQLWrapper import SPARQLWrapper, JSON, XML, N3, RDF, CSV, TSV
from bs4 import BeautifulSoup
import requests
import re
import numpy as np

# %%
data = pd.read_csv("Suicides_wikipedia_scrapping_fr.csv", encoding="utf-8-sig", delimiter=",")
data.head()
# Out:
#                      Name                                               Link  \
# 0            Adolfo_Couve         https://fr.wikipedia.org/wiki/Adolfo_Couve
# 1               Boaz_Arad            https://fr.wikipedia.org/wiki/Boaz_Arad
# 2            Ralph_Barton         https://fr.wikipedia.org/wiki/Ralph_Barton
# 3             Mark_Campos          https://fr.wikipedia.org/wiki/Mark_Campos
# 4  Michel_Caron_(artiste)  https://fr.wikipedia.org/wiki/Michel_Caron_(ar...
#
#                                              Content
# 0  ['id="Biographie">Biographie[modifier', '|', '...
# 1  ['id="Biographie">Biographie[modifier', '|', '...
# 2  ['id="Biographie">Biographie[modifier', '|', '...
# 3  ['id="Biographie">Biographie[modifier', '|', '...
# 4  ['id="Biographie">Biographie[modifier', '|', '...

# %%
listeName = data["Name"].values

# %% [markdown]
# ## Requests for abstract, birthdate, birthplace, deathdate, deathplace, and gender

# %%
abstract = []
birthdate = []
birthplace = []
deathdate = []
deathplace = []
gender = []

# %%
i = 0
len(listeName)
# Out:
# 2099

# %%
for name in range(len(listeName)):
    if(name % 201 == 0):
        print((name/len(listeName)*100),"% du travail effectué !")
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    sparql.setQuery("""PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?abstract ?birthdate ?deathdate ?birthplace ?deathplace ?gender
    WHERE { <http://dbpedia.org/resource/"""+listeName[name]+"""> dbo:abstract ?abstract.
    <http://dbpedia.org/resource/"""+listeName[name]+"""> dbo:birthDate ?birthdate.
    <http://dbpedia.org/resource/"""+listeName[name]+"""> dbo:deathDate ?deathdate.
    <http://dbpedia.org/resource/"""+listeName[name]+"""> dbo:birthPlace ?birthplace.
    <http://dbpedia.org/resource/"""+listeName[name]+"""> dbo:deathPlace ?deathplace.
    <http://dbpedia.org/resource/"""+listeName[name]+"""> foaf:gender ?gender}
    """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    if (results["results"]["bindings"] != []):
        results = results["results"]["bindings"][0]
        abstract.append(results["abstract"]["value"])
        birthdate.append(results["birthdate"]["value"])
        birthplace.append(results["birthplace"]["value"])
        deathdate.append(results["deathdate"]["value"])
        deathplace.append(results["deathplace"]["value"])
        gender.append(results["gender"]["value"])
    else:
        i+=1
        if (i%10 == 0):
            print("nombre de données manquantes :", i)
        abstract.append("")
        birthdate.append("")
        birthplace.append("")
        deathdate.append("")
        deathplace.append("")
        gender.append("")
print("il manque", (i/len(listeName))*100,"% des données")
# Out:
# 0.0 % du travail effectué !
# nombre de données manquantes : 10
# nombre de données manquantes : 20
# nombre de données manquantes : 30
# nombre de données manquantes : 40
# nombre de données manquantes : 50
# nombre de données manquantes : 60
# 9.575988565983803 % du travail effectué !
# nombre de données manquantes : 70
# nombre de données manquantes : 80
# nombre de données manquantes : 90
# nombre de données manquantes : 100
# nombre de données manquantes : 110
# nombre de données manquantes : 120
# nombre de données manquantes : 130
# 19.151977131967605 % du travail effectué !
# nombre de données manquantes : 140
# nombre de données manquantes : 150
# nombre de données manquantes : 160
# nombre de données manquantes : 170
# nombre de données manquantes : 180
# nombre de données manquantes : 190
# nombre de données manquantes : 200
# nombre de données manquantes : 210
# 28.727965697951408 % du travail effectué !
# nombre de données manquantes : 220
# nombre de données manquantes : 230
# nombre de données manquantes : 240
# nombre de données manquantes : 250
# nombre de données manquantes : 260
# nombre de données manquantes : 270
# nombre de données manquantes : 280
# nombre de données manquantes : 290
# 38.30395426393521 % du travail effectué !
# nombre de données manquantes : 300
# nombre de données manquantes : 310
# nombre de données manquantes : 320
# nombre de données manquantes : 330
# nombre de données manquantes : 340
# nombre de données manquantes : 350
# nombre de données manquantes : 360
# nombre de données manquantes : 370
# 47.87994282991901 % du travail effectué !
# nombre de données manquantes : 380
# nombre de données manquantes : 390
# nombre de données manquantes : 400
# nombre de données manquantes : 410
# nombre de données manquantes : 420
# nombre de données manquantes : 430
# nombre de données manquantes : 440
# nombre de données manquantes : 450
# 57.455931395902816 % du travail effectué !
# nombre de données manquantes : 460
# nombre de données manquantes : 470
# nombre de données manquantes : 480
# nombre de données manquantes : 490
# nombre de données manquantes : 500
# nombre de données manquantes : 510
# nombre de données manquantes : 520
# nombre de données manquantes : 530
# nombre de données manquantes : 540
# nombre de données manquantes : 550
# nombre de données manquantes : 560
# nombre de données manquantes : 570
# nombre de données manquantes : 580
# 67.03191996188662 % du travail effectué !
# nombre de données manquantes : 590
# nombre de données manquantes : 600
# nombre de données manquantes : 610
# nombre de données manquantes : 620
# nombre de données manquantes : 630
# nombre de données manquantes : 640
# nombre de données manquantes : 650
# nombre de données manquantes : 660
# nombre de données manquantes : 670
# nombre de données manquantes : 680
# nombre de données manquantes : 690
# 76.60790852787042 % du travail effectué !
# nombre de données manquantes : 700
# nombre de données manquantes : 710
# nombre de données manquantes : 720
# nombre de données manquantes : 730
# nombre de données manquantes : 740
# nombre de données manquantes : 750
# nombre de données manquantes : 760
# nombre de données manquantes : 770
# nombre de données manquantes : 780
# nombre de données manquantes : 790
# 86.18389709385421 % du travail effectué !
# nombre de données manquantes : 800
# nombre de données manquantes : 810
# nombre de données manquantes : 820
# nombre de données manquantes : 830
# nombre de données manquantes : 840
# nombre de données manquantes : 850
# nombre de données manquantes : 860
# nombre de données manquantes : 870
# nombre de données manquantes : 880
# nombre de données manquantes : 890
# nombre de données manquantes : 900
# nombre de données manquantes : 910
# 95.75988565983802 % du travail effectué !
# nombre de données manquantes : 920
# nombre de données manquantes : 930
# nombre de données manquantes : 940
# nombre de données manquantes : 950
# nombre de données manquantes : 960
# nombre de données manquantes : 970
# nombre de données manquantes : 980
# il manque 46.73654121010004 % des données

# %% [markdown]
# ## The birthplace and deathplace without links

# %%
birthplace_clean = [""]*len(birthplace)
deathplace_clean = [""]*len(deathplace)
for i in range(len(birthplace)):
    for j in range(28, len(birthplace[i])):
        birthplace_clean[i] += birthplace[i][j]
for i in range(len(deathplace)):
    for j in range(28, len(deathplace[i])):
        deathplace_clean[i] += deathplace[i][j]

# %%
data["abstract"] = abstract
data["birthdate"] = birthdate
data["birthplace_clean"] = birthplace_clean
data["birthplace"] = birthplace
data["deathdate"] = deathdate
data["deathplace_clean"] = deathplace_clean
data["deathplace"] = deathplace
data["gender"] = gender

data.head()
# Out:
#                      Name                                               Link  \
# 0            Adolfo_Couve         https://fr.wikipedia.org/wiki/Adolfo_Couve
# 1               Boaz_Arad            https://fr.wikipedia.org/wiki/Boaz_Arad
# 2            Ralph_Barton         https://fr.wikipedia.org/wiki/Ralph_Barton
# 3             Mark_Campos          https://fr.wikipedia.org/wiki/Mark_Campos
# 4  Michel_Caron_(artiste)  https://fr.wikipedia.org/wiki/Michel_Caron_(ar...
#
#                                              Content  \
# 0  ['id="Biographie">Biographie[modifier', '|', '...
# 1  ['id="Biographie">Biographie[modifier', '|', '...
# 2  ['id="Biographie">Biographie[modifier', '|', '...
# 3  ['id="Biographie">Biographie[modifier', '|', '...
# 4  ['id="Biographie">Biographie[modifier', '|', '...
#
#                                             abstract  birthdate  \
# 0  Adolfo Couve Rioseco (Valparaíso, 28 de marzo ...  1940-3-28
# 1
# 2  Ralph Waldo Emerson Barton (14 août 1891 – 19 ...  1891-8-14
# 3
# 4
#
#         birthplace_clean                                         birthplace  \
# 0             Valparaíso             http://dbpedia.org/resource/Valparaíso
# 1
# 2  Kansas_City,_Missouri  http://dbpedia.org/resource/Kansas_City,_Missouri
# 3
# 4
#
#    deathdate         deathplace_clean  \
# 0  1998-3-11         Cartagena,_Chile
# 1
# 2  1931-5-19  New_York_City,_New_York
# 3
# 4
#
#                                           deathplace gender
# 0       http://dbpedia.org/resource/Cartagena,_Chile   male
# 1
# 2  http://dbpedia.org/resource/New_York_City,_New...   male
# 3
# 4

# %% [markdown]
# ## Dataframe where the sparql request does not worked (for analysis)

# %%
data_errors = data[(data['abstract'] == "")]
#data = data[(data['Content'] != [])]
print("la longueur finale du dataframe d'erreurs est :", data_errors.shape[0])
data_errors.head()
# Out:
# la longueur finale du dataframe d'erreurs est : 981
#                      Name                                               Link  \
# 1               Boaz_Arad            https://fr.wikipedia.org/wiki/Boaz_Arad
# 3             Mark_Campos          https://fr.wikipedia.org/wiki/Mark_Campos
# 4  Michel_Caron_(artiste)  https://fr.wikipedia.org/wiki/Michel_Caron_(ar...
# 5   Cassandre_(graphiste)  https://fr.wikipedia.org/wiki/Cassandre_(graph...
# 6      Jack_Cole_(auteur)   https://fr.wikipedia.org/wiki/Jack_Cole_(auteur)
#
#                                              Content abstract birthdate  \
# 1  ['id="Biographie">Biographie[modifier', '|', '...
# 3  ['id="Biographie">Biographie[modifier', '|', '...
# 4  ['id="Biographie">Biographie[modifier', '|', '...
# 5  ['id="Biographie">Biographie[modifier', '|', '...
# 6  ['id="Biographie">Biographie[modifier', '|', '...
#
#   birthplace_clean birthplace deathdate deathplace_clean deathplace gender
# 1
# 3
# 4
# 5
# 6

# %% [markdown]
# ## Dataframe where the sparql requests worked

# %%
data = data[(data['abstract'] != "")]
#data = data[(data['Content'] != [])]
print("la longueur finale du dataframe est :", data.shape[0])
data.head()
# Out:
# la longueur finale du dataframe est : 1118
#               Name                                          Link  \
# 0     Adolfo_Couve    https://fr.wikipedia.org/wiki/Adolfo_Couve
# 2     Ralph_Barton    https://fr.wikipedia.org/wiki/Ralph_Barton
# 8   Jack_Goldstein  https://fr.wikipedia.org/wiki/Jack_Goldstein
# 11   Paul_Markwitz   https://fr.wikipedia.org/wiki/Paul_Markwitz
# 13  Virginia_Woolf  https://fr.wikipedia.org/wiki/Virginia_Woolf
#
#                                               Content  \
# 0   ['id="Biographie">Biographie[modifier', '|', '...
# 2   ['id="Biographie">Biographie[modifier', '|', '...
# 8                                                  []
# 11  ['id="Biographie">Biographie[modifier', '|', '...
# 13  ['id="Biographie">Biographie[modifier', '|', '...
#
#                                              abstract   birthdate  \
# 0   Adolfo Couve Rioseco (Valparaíso, 28 de marzo ...   1940-3-28
# 2   Ralph Waldo Emerson Barton (14 août 1891 – 19 ...   1891-8-14
# 8   Jack Goldstein (* 27. September 1945 in Montre...   1945-9-27
# 11  Paul E. Markwitz (* 16. Juli 1908 in Berlin; †...   1908-7-16
# 13  Adeline Virginia Woolf (née Stephen; 25 Januar...  1882-01-25
#
#          birthplace_clean                                         birthplace  \
# 0              Valparaíso             http://dbpedia.org/resource/Valparaíso
# 2   Kansas_City,_Missouri  http://dbpedia.org/resource/Kansas_City,_Missouri
# 8                Montreal               http://dbpedia.org/resource/Montreal
# 11                 Berlin                 http://dbpedia.org/resource/Berlin
# 13             Kensington             http://dbpedia.org/resource/Kensington
#
#      deathdate            deathplace_clean  \
# 0    1998-3-11            Cartagena,_Chile
# 2    1931-5-19     New_York_City,_New_York
# 8    2003-3-14  San_Bernardino,_California
# 11  1968-03-19                      Berlin
# 13  1941-03-28                       Lewes
#
#                                            deathplace  gender
# 0        http://dbpedia.org/resource/Cartagena,_Chile    male
# 2   http://dbpedia.org/resource/New_York_City,_New...    male
# 8   http://dbpedia.org/resource/San_Bernardino,_Ca...    male
# 11                 http://dbpedia.org/resource/Berlin    male
# 13                  http://dbpedia.org/resource/Lewes  female

# %% [markdown]
# ## Save to .csv

# %%
data.to_csv("Suicide_withDBPedia_Values_fr.csv",index=False, sep=",", encoding='utf-8-sig')

# %%
data_errors.to_csv("Suicide_withDBPedia_Values_errors_fr.csv",index=False, sep=",", encoding='utf-8-sig')

# %% [markdown]
# ## Match birthplace with countries

# %%
listeBirthplaceCountries = data["birthplace_clean"].values
countries = []
i = 0
len(listeBirthplaceCountries)
# Out:
# 1118

# %%
for country in range(len(listeBirthplaceCountries)):
    if(country % 111 == 0):
        print((country/len(listeBirthplaceCountries)*100),"% du travail effectué !")
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    sparql.setQuery("""PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?country
    WHERE { <http://dbpedia.org/resource/"""+listeBirthplaceCountries[country]+"""> dbo:country ?country}
    """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    if (results["results"]["bindings"] != []):
        results = results["results"]["bindings"][0]
        countries.append(results["country"]["value"])
    else:
        i+=1
        if (i%10 == 0):
            print("nombre de données manquantes :", i)
        countries.append("")
# Out:
# 0.0 % du travail effectué !
# nombre de données manquantes : 10
# nombre de données manquantes : 20
# nombre de données manquantes : 30
# nombre de données manquantes : 40
# 9.928443649373882 % du travail effectué !
# nombre de données manquantes : 50
# nombre de données manquantes : 60
# nombre de données manquantes : 70
# nombre de données manquantes : 80
# 19.856887298747765 % du travail effectué !
# nombre de données manquantes : 90
# nombre de données manquantes : 100
# nombre de données manquantes : 110
# nombre de données manquantes : 120
# 29.785330948121647 % du travail effectué !
# nombre de données manquantes : 130
# nombre de données manquantes : 140
# nombre de données manquantes : 150
# 39.71377459749553 % du travail effectué !
# nombre de données manquantes : 160
# nombre de données manquantes : 170
# nombre de données manquantes : 180
# 49.642218246869405 % du travail effectué !
# nombre de données manquantes : 190
# nombre de données manquantes : 200
# nombre de données manquantes : 210
# nombre de données manquantes : 220
# 59.570661896243294 % du travail effectué !
# nombre de données manquantes : 230
# nombre de données manquantes : 240
# nombre de données manquantes : 250
# nombre de données manquantes : 260
# nombre de données manquantes : 270
# 69.49910554561717 % du travail effectué !
# nombre de données manquantes : 280
# nombre de données manquantes : 290
# nombre de données manquantes : 300
# 79.42754919499106 % du travail effectué !
# nombre de données manquantes : 310
# nombre de données manquantes : 320
# nombre de données manquantes : 330
# 89.35599284436493 % du travail effectué !
# nombre de données manquantes : 340
# nombre de données manquantes : 350
# nombre de données manquantes : 360
# 99.28443649373881 % du travail effectué !
# nombre de données manquantes : 370

# %%
birthcountry_clean = [""]*len(countries)
for i in range(len(countries)):
    for j in range(28, len(countries[i])):
        birthcountry_clean[i] += countries[i][j]
data["birthCountry"] = birthcountry_clean
data.head()
# Out:
#               Name                                          Link  \
# 0     Adolfo_Couve    https://fr.wikipedia.org/wiki/Adolfo_Couve
# 2     Ralph_Barton    https://fr.wikipedia.org/wiki/Ralph_Barton
# 8   Jack_Goldstein  https://fr.wikipedia.org/wiki/Jack_Goldstein
# 11   Paul_Markwitz   https://fr.wikipedia.org/wiki/Paul_Markwitz
# 13  Virginia_Woolf  https://fr.wikipedia.org/wiki/Virginia_Woolf
#
#                                               Content  \
# 0   ['id="Biographie">Biographie[modifier', '|', '...
# 2   ['id="Biographie">Biographie[modifier', '|', '...
# 8                                                  []
# 11  ['id="Biographie">Biographie[modifier', '|', '...
# 13  ['id="Biographie">Biographie[modifier', '|', '...
#
#                                              abstract   birthdate  \
# 0   Adolfo Couve Rioseco (Valparaíso, 28 de marzo ...   1940-3-28
# 2   Ralph Waldo Emerson Barton (14 août 1891 – 19 ...   1891-8-14
# 8   Jack Goldstein (* 27. September 1945 in Montre...   1945-9-27
# 11  Paul E. Markwitz (* 16. Juli 1908 in Berlin; †...   1908-7-16
# 13  Adeline Virginia Woolf (née Stephen; 25 Januar...  1882-01-25
#
#          birthplace_clean                                         birthplace  \
# 0              Valparaíso             http://dbpedia.org/resource/Valparaíso
# 2   Kansas_City,_Missouri  http://dbpedia.org/resource/Kansas_City,_Missouri
# 8                Montreal               http://dbpedia.org/resource/Montreal
# 11                 Berlin                 http://dbpedia.org/resource/Berlin
# 13             Kensington             http://dbpedia.org/resource/Kensington
#
#      deathdate            deathplace_clean  \
# 0    1998-3-11            Cartagena,_Chile
# 2    1931-5-19     New_York_City,_New_York
# 8    2003-3-14  San_Bernardino,_California
# 11  1968-03-19                      Berlin
# 13  1941-03-28                       Lewes
#
#                                            deathplace  gender    birthCountry
# 0        http://dbpedia.org/resource/Cartagena,_Chile    male           Chile
# 2   http://dbpedia.org/resource/New_York_City,_New...    male   United_States
# 8   http://dbpedia.org/resource/San_Bernardino,_Ca...    male          Canada
# 11                 http://dbpedia.org/resource/Berlin    male         Germany
# 13                  http://dbpedia.org/resource/Lewes  female  United_Kingdom

# %% [markdown]
# ## Where the birthcountry requests failed (for analysis)

# %%
data[(data['birthCountry'] == "")]
# Out:
#                         Name  \
# 17        Jean-François_Adam
# 27           Pierre_Batcheff
# 29              Rémy_Belvaux
# 32          Jonathan_Brandis
# 33            Claudio_Camaso
# 34      Arthur_Edmund_Carewe
# 35             Walmor_Chagas
# 36             Leslie_Cheung
# 37           Ronny_Coutteure
# 39                 Karl_Dane
# 41           Patrick_Dewaere
# 43        Richard_Farnsworth
# 45               Ed_Flanders
# 48            Vladimir_Fogel
# 57              Daisuke_Gōri
# 62                Tony_Halme
# 64         Raimund_Harmstorf
# 77             Andrew_Koenig
# 86           Mitsuyasu_Maeno
# 87               Shinji_Maki
# 91             Freddie_Mills
# 93             Jorge_Mistral
# 97                Masaya_Oki
# 100             Park_Yong-ha
# 102           Luigi_Pistilli
# 103           Daniel_Pollock
# 107              Jason_Raize
# 108          David_Rappaport
# 120            Walter_Slezak
# 121           Everett_Sloane
# ...                      ...
# 1864             Kalikho_Pul
# 1878       Bharat_Raj_Upreti
# 1883     Jangarh_Singh_Shyam
# 1888         Frederick_Fleet
# 1893             Hans_Litten
# 1895         Conrad_Schumann
# 1897           Yun_Hyon-seok
# 1921            Mike_Awesome
# 1926           Justin_Pierce
# 1934     Duncan_Gordon_Boyes
# 1941      Danguolė_Rasalaitė
# 1946  Edwin_Howard_Armstrong
# 1950      Ruslana_Korshunova
# 1975        Nicos_Poulantzas
# 1979                May_Ayim
# 1982             Joseph_Wulf
# 2014         George_R._Price
# 2016    Louis_Léopold_Robert
# 2048         Chujiro_Hayashi
# 2050            Hōjō_Ujimasa
# 2059            Maki_Yasuomi
# 2067            Oda_Nobunaga
# 2068            Oda_Nobutada
# 2070        Ōshio_Heihachirō
# 2071         Ōuchi_Yoshitaka
# 2076            Sen_no_Rikyū
# 2078         Shibata_Katsuie
# 2082          Saigō_Takamori
# 2094          Watanabe_Kazan
# 2098          Zusho_Hirosato
#
#                                                    Link  \
# 17     https://fr.wikipedia.org/wiki/Jean-François_Adam
# 27        https://fr.wikipedia.org/wiki/Pierre_Batcheff
# 29           https://fr.wikipedia.org/wiki/Rémy_Belvaux
# 32       https://fr.wikipedia.org/wiki/Jonathan_Brandis
# 33         https://fr.wikipedia.org/wiki/Claudio_Camaso
# 34    https://fr.wikipedia.org/wiki/Arthur_Edmund_Ca...
# 35          https://fr.wikipedia.org/wiki/Walmor_Chagas
# 36          https://fr.wikipedia.org/wiki/Leslie_Cheung
# 37        https://fr.wikipedia.org/wiki/Ronny_Coutteure
# 39              https://fr.wikipedia.org/wiki/Karl_Dane
# 41        https://fr.wikipedia.org/wiki/Patrick_Dewaere
# 43     https://fr.wikipedia.org/wiki/Richard_Farnsworth
# 17    ['id="Biographie">Biographie[modifier', '|', '...
# 27    ['id="Biographie">Biographie[modifier', '|', '...
# 29    ['id="Biographie">Biographie[modifier', '|', '...
# 32    ['id="Biographie">Biographie[modifier', '|', '...
# 33    ['id="Biographie">Biographie[modifier', '|', '...
# 34    ['id="Biographie">Biographie[modifier', '|', '...
# 35                                                   []
# 36    ['id="Biographie">Biographie[modifier', '|', '...
# 37    ['id="Biographie">Biographie[modifier', '|', '...
# 39    ['id="Biographie">Biographie[modifier', '|', '...
# 41    ['id="Biographie">Biographie[modifier', '|', '...
# 43                                                   []
# 45    ['id="Biographie">Biographie[modifier', '|', '...
# 48    ['id="Biographie">Biographie[modifier', '|', '...
# 57                                                   []
# 62                                                   []
# 64    ['id="Biographie">Biographie[modifier', '|', '...
# 77    ['id="Biographie">Biographie[modifier', '|', '...
# 86    ['id="Biographie">Biographie[modifier', '|', '...
# 87    ['id="Biographie">Biographie[modifier', '|', '...
# 91                                                   []
# 93    ['id="Biographie">Biographie[modifier', '|', '...
# 97    ['id="Biographie">Biographie[modifier', '|', '...
# 100   ['id="Biographie">Biographie[modifier', '|', '...
# 102   ['id="Biographie">Biographie[modifier', '|', '...
# 103                                                  []
# 107                                                  []
# 108   ['id="Biographie">Biographie[modifier', '|', '...
# 120   ['id="Biographie">Biographie[modifier', '|', '...
# 121   ['id="Biographie">Biographie[modifier', '|', '...
# ...                                                 ...
# 1864  ['id="Biographie">Biographie[modifier', '|', '...
# 1878  ['id="Biographie">Biographie[modifier', '|', '...
# 1883  ['id="Biographie">Biographie[modifier', '|', '...
# 1888  ['id="Biographie">Biographie[modifier', '|', '...
# 1893  ['id="Biographie">Biographie[modifier', '|', '...
# 1895                                                 []
# 1897  ['id="Biographie">Biographie[modifier', '|', '...
# 1921                                                 []
# 1926  ['id="Biographie">Biographie[modifier', '|', '...
# 1934  ['id="Biographie">Biographie[modifier', '|', '...
# 1941                                                 []
# 1946  ['id="Biographie">Biographie[modifier', '|', '...
# 1950  ['id="Biographie">Biographie[modifier', '|', '...
# 1975  ['id="Biographie">Biographie[modifier', '|', '...
# 1979  ['id="Biographie">Biographie[modifier', '|', '...
# 1982  ['id="Biographie">Biographie[modifier', '|', '...
# 2014                                                 []
# 2016  ['id="Biographie">Biographie[modifier', '|', '...
# 2048                                                 []
# 2050  ['id="Biographie">Biographie[modifier', '|', '...
# 2059                                                 []
# 2067  ['id="Biographie">Biographie[modifier', '|', '...
# 2068                                                 []
# 2070  ['id="Biographie">Biographie[modifier', '|', '...
# 2071                                                 []
# 2076  ['id="Biographie">Biographie[modifier', '|', '...
# 2078                                                 []
# 2082                                                 []
# 2094  ['id="Biographie">Biographie[modifier', '|', '...
# 2098  ['id="Biographie">Biographie[modifier', '|', '...
#
#                                                abstract   birthdate  \
# 17    Jean-François AdamFichier:Image manquante.jpg ...   1938-2-14
# 27    Pierre Batcheff (born Piotr Bachev; 23 June 19...   1901-6-23
# 29    Rémy Belvaux (*Namur, 1967 - † 4 de septiembre...  1966-11-10
# 32    Jonathan Gregory Brandis (April 13, 1976 – Nov...   1976-4-13
# 2059        http://dbpedia.org/resource/Kurume,_Fukuoka  1864-08-22
# 2067         http://dbpedia.org/resource/Owari_Province   1582-6-21
# 2068         http://dbpedia.org/resource/Owari_Province   1582-6-21
# 2070     http://wikidata.dbpedia.org/resource/Q17218922    1837-5-1
# 2071   http://dbpedia.org/resource/Yamaguchi,_Yamaguchi  1551-09-30
# 2076           http://dbpedia.org/resource/Sakai,_Osaka   1591-4-21
# 2078         http://dbpedia.org/resource/Owari_Province    1583-6-6
# 2082       http://dbpedia.org/resource/Satsuma_Province   1877-9-24
# 2094     http://wikidata.dbpedia.org/resource/Q17215107  1841-11-23
# 2098         http://dbpedia.org/resource/Satsuma_Domain   1849-1-13
#
#                deathplace_clean  \
# 17                       France
# 27                        Paris
# 29                Orry-la-Ville
# 32                  Los_Angeles
# 33                        Italy
# 34     Santa_Monica,_California
# 35                Guaratinguetá
# 36           Central,_Hong_Kong
# 37                       Fretin
# 39                  Los_Angeles
# 41                        Paris
# 43                United_States
# 45            Denny,_California
# 48                         USSR
# 57                Nakano,_Tokyo
# 62                     Helsinki
# 64                Marktoberdorf
# 77                    Vancouver
# 86                        Tokyo
# 87                   Tama_River
# 91                      England
# 93                       Mexico
# 97                         Keiō
# 100                 South_Korea
# 102                       Italy
# 103                      Sydney
# 107       Yass,_New_South_Wales
# 108                  California
# 120                    New_York
# 121                  California
# ...                         ...
# 1864          Arunachal_Pradesh
# 1878                  Kathmandu
# 1883                      Japan
# 1888                Southampton
# 1893  Dachau_concentration_camp
# 1895                 Oberbayern
# 1897        Dongdaemun_District
# 1921             Tampa,_Florida
# 1926                  Las_Vegas
# 1934                    Dunedin
# 1941                      Malmö
# 1946           New_York_(state)
# 1950                  Manhattan
# 1975                      Paris
# 1979                     Berlin
# 1982             Charlottenburg
# 2014             United_Kingdom
# 2016                     Venice
# 2048                      Japan
# 2050                      Japan
# 2059            Settsu_Province
# 2067                   Honnō-ji
# 2068              Azuchi_Castle
# 2070         resource/Q17213572
# 2071          Nagato,_Yamaguchi
# 2076                      Kyoto
# 2078               Fukui,_Fukui
# 2082       Kagoshima_prefecture
# 2094              Tahara,_Aichi
# 2098                        Edo
#
#                                              deathplace  gender birthCountry
# 17                   http://dbpedia.org/resource/France    male
# 27                    http://dbpedia.org/resource/Paris    male
# 29            http://dbpedia.org/resource/Orry-la-Ville    male
# 32              http://dbpedia.org/resource/Los_Angeles    male
# 33                    http://dbpedia.org/resource/Italy    male
# 34    http://dbpedia.org/resource/Santa_Monica,_Cali...    male
# 35            http://dbpedia.org/resource/Guaratinguetá    male
# 36       http://dbpedia.org/resource/Central,_Hong_Kong    male
# 37                   http://dbpedia.org/resource/Fretin    male
# 39              http://dbpedia.org/resource/Los_Angeles    male
# 41                    http://dbpedia.org/resource/Paris    male
# 43            http://dbpedia.org/resource/United_States    male
# 45        http://dbpedia.org/resource/Denny,_California    male
# 48                     http://dbpedia.org/resource/USSR    male
# 57            http://dbpedia.org/resource/Nakano,_Tokyo    male
# 62                 http://dbpedia.org/resource/Helsinki    male
# 64            http://dbpedia.org/resource/Marktoberdorf    male
# 77                http://dbpedia.org/resource/Vancouver    male
# 86                    http://dbpedia.org/resource/Tokyo    male
# 87               http://dbpedia.org/resource/Tama_River    male
# 91                  http://dbpedia.org/resource/England    male
# 93                   http://dbpedia.org/resource/Mexico    male
# 97                     http://dbpedia.org/resource/Keiō    male
# 100             http://dbpedia.org/resource/South_Korea    male
# 102                   http://dbpedia.org/resource/Italy    male
# 103                  http://dbpedia.org/resource/Sydney    male
# 107   http://dbpedia.org/resource/Yass,_New_South_Wales    male
# 108              http://dbpedia.org/resource/California    male
# 120                http://dbpedia.org/resource/New_York    male
# 121              http://dbpedia.org/resource/California    male
# ...                                                 ...     ...          ...
# 1864      http://dbpedia.org/resource/Arunachal_Pradesh    male
# 1878              http://dbpedia.org/resource/Kathmandu    male
# 1883                  http://dbpedia.org/resource/Japan    male
# 1888            http://dbpedia.org/resource/Southampton    male
# 1893  http://dbpedia.org/resource/Dachau_concentrati...    male
# 1895             http://dbpedia.org/resource/Oberbayern    male
# 1897    http://dbpedia.org/resource/Dongdaemun_District    male
# 1921         http://dbpedia.org/resource/Tampa,_Florida    male
# 1926              http://dbpedia.org/resource/Las_Vegas    male
# 1934                http://dbpedia.org/resource/Dunedin    male
# 1941                  http://dbpedia.org/resource/Malmö  female
# 1946       http://dbpedia.org/resource/New_York_(state)    male
# 1950              http://dbpedia.org/resource/Manhattan  female
# 1975                  http://dbpedia.org/resource/Paris    male
# 1979                 http://dbpedia.org/resource/Berlin  female
# 1982         http://dbpedia.org/resource/Charlottenburg    male
# 2014         http://dbpedia.org/resource/United_Kingdom    male
# 2016                 http://dbpedia.org/resource/Venice    male
# 2048                  http://dbpedia.org/resource/Japan    male
# 2050                  http://dbpedia.org/resource/Japan    male
# 2059        http://dbpedia.org/resource/Settsu_Province    male
# 2067               http://dbpedia.org/resource/Honnō-ji    male
# 2068          http://dbpedia.org/resource/Azuchi_Castle    male
# 2070     http://wikidata.dbpedia.org/resource/Q17213572    male
# 2071      http://dbpedia.org/resource/Nagato,_Yamaguchi    male
# 2076                  http://dbpedia.org/resource/Kyoto    male
# 2078           http://dbpedia.org/resource/Fukui,_Fukui    male
# 2082   http://dbpedia.org/resource/Kagoshima_prefecture    male
# 2094          http://dbpedia.org/resource/Tahara,_Aichi    male
# 2098                    http://dbpedia.org/resource/Edo    male
#
# [376 rows x 12 columns]

# %% [markdown]
# It could be due to the fact that birthplace_clean certains time does not contains the city, but the country of the birth. So it will be tries to find if the value is a country with a sparql request.

# %% [markdown]
# if the value is a country, it has a capital. So a request is performed to know access to all of the values that are countries with a request that say "if the value has a capital, add it to the array"

# %%
capitals = ""
capital_clean = [""]*len(data)
for i in range(len(data)):
    if(data.iloc[i, -1] == ""):
        sparql = SPARQLWrapper("http://dbpedia.org/sparql")
        sparql.setQuery("""PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            SELECT ?capital
            WHERE { <http://dbpedia.org/resource/"""+data.iloc[i, 5]+"""> dbo:capital ?capital}
            """)
        sparql.setReturnFormat(JSON)
        results = sparql.query().convert()
        if(results["results"]["bindings"] != []):
            capital = results["results"]["bindings"][0]["capital"]["value"]
            for j in range(28, len(capital)):
                capital_clean[i] += capital[j]

# %% [markdown]
# ## replace the value in birthCountry by birthplace value if the birthCountry is unknown and the birthplace have a capital (i.e., is a country)

# %%
for i in range(len(data)):
    if(birthcountry_clean[i] == "" and capital_clean[i] != ""):
        if(capital_clean[i] == "United_States"):
            capital_clean[i] = "United_States_of_America"
        print("capital :", capital_clean[i])
        birthcountry_clean[i] = birthplace_clean[i]
    elif(birthcountry_clean[i] =="List_of_historical_capitals_of_Hungary"):
        birthcountry_clean[i] = "Hungary"
# Out:
# capital : Paris
# Country :
# capital : Beijing
# Country : Kensington
# capital : City_of_Brussels
# Country :
# capital : Rome
# Country : Brooklyn
# capital : Bursa
# Country :
# capital : Brasília
# Country :
# capital : City_of_Brussels
# Country : Mexico_City
# capital : Copenhagen
# Country : Moscow
# capital : Washington,_D.C.
# Country : China
# capital : Moscow
# Country : Figeac
# capital : Tokyo
# Country : Hong_Kong
# capital : Berlin
# Country :
# capital : Washington,_D.C.
# Country : Vienna
# capital : Tokyo
# Country : Japan
# capital : Seoul
# Country : Iowa
# capital : Rome
# Country : California
# capital : Canberra
# Country : Edo
# capital : Washington,_D.C.
# Country : Forst_(Lausitz)
# capital : Budapest
# Country : Minsk
# capital : Buenos_Aires
# Country : Saint-Loubès
# capital : Paris
# Country :
# capital : Cairo
# Country : Michigan
# capital : Warsaw
# Country : Vienna
# capital : Budapest
# Country : Talence
# capital : Paris
# Country :
# capital : Budapest
# Country : St._Cloud,_Minnesota
# capital : Kiev
# Country :
# capital : Berlin
# Country : Long_Island
# capital : Paris
# Country : Alameda,_California
# capital : Berlin
# Country : Egypt
# capital : Nicosia
# Country :
# capital : Rome
# Country :
# capital : Saint_Helier,_Jersey
# Country : Fairchild,_Wisconsin
# capital : Stockholm
# Country : Paris
# capital : Washington,_D.C.
# Country : France
# capital : Budapest
# Country : Vienna
# capital : Santiago
# Country :
# capital : Berlin
# Country : Ozark,_Arkansas
# capital : Bursa
# Country : Trafford
# capital : Helsinki
# Country : West_Riding_of_Yorkshire
# capital : Vitebsk
# Country : Stockholm
# capital : Paris
# Country : Melbourne
# capital : Berlin
# Country : Sydney
# capital : Havana
# Country : Lisieux
# capital : Tokyo
# Country :
# capital : Budapest
# Country : El_Paso,_Texas
# capital : Bogotá
# Country : Akron,_Ohio
# capital : Paris
# Country : Hampstead
# capital : Sofia
# Country : Vienna
# capital : Vilnius
# Country : Shreveport,_Louisiana
# capital : Prague
# Country : Alentejo
# capital : Beijing
# Country : Los_Angeles
# capital : Tehran
# Country :
# capital : Tokyo
# Country :
# capital : Warsaw
# Country : New_York_City
# capital : Washington,_D.C.
# Country : The_Hague
# capital : Budapest
# Country :
# capital : Königsberg
# Country : Oise
# capital : Santiago
# Country : Girona
# capital : Managua
# Country : Washington_Heights,_Manhattan
# capital : Zagreb
# Country : Garrettsville,_Ohio
# capital : St._George's,_Grenada
# Country : Paris
# capital : Zhytomyr
# Country : Des_Moines,_Iowa
# capital : Santo_Domingo
# Country : Bulgaria
# capital : Nanjing
# Country :
# capital : Warsaw
# Country : Nuremberg
# capital : Ottawa
# Country : Vila_Viçosa
# capital : Tokyo
# Country : Bordeaux
# capital : Saint_Petersburg
# Country :
# capital : City_of_Brussels
# Country :
# capital : Tallinn
# Country : London
# capital : Vienna
# Country :
# capital : Budapest
# Country : Norrköping
# capital : Budapest
# Country : Budapest
# capital : Berlin
# Country : Banja_Luka
# capital : Budapest
# Country : Turin
# capital : Dresden
# Country : United_States
# capital : Vienna
# Country :
# capital : Paris
# Country : Shinjuku,_Tokyo
# capital : Sucre
# Country : Żytomierz
# capital : Paris
# Country : Hudson,_Ohio
# capital : City_of_Brussels
# Country : Schenectady,_New_York
# capital : Rome
# Country : Lincoln,_Nebraska
# capital : Budapest
# Country :
# capital : East_Berlin
# Country :
# capital : Rome
# Country :
# capital : Prague
# Country : Corona,_California
# capital : Prague
# Country : Taketa,_Ōita
# capital : Seoul
# Country :
# capital : Oslo
# Country : Biebrich_(Wiesbaden)
# capital : Rome
# Country : East_Prussia
# capital : San_José,_Costa_Rica
# Country :
# capital : Madrid
# Country : resource/Q390178
# capital : Abuja
# Country :
# capital : Paris
# Country : Szubin
# capital : Victoria,_Hong_Kong
# Country :
# capital : Bucharest
# Country : Chester,_Vermont
# capital : Rome
# Country : Courland
# capital : Washington,_D.C.
# Country :
# capital : Berlin
# Country :
# capital : Tokyo
# Country : Córdoba,_Argentina
# capital : Berlin
# Country : Berlin
# capital : Dresden
# Country :
# capital : Rome
# Country : Wakayama_Prefecture
# capital : Paris
# Country :
# capital : Oslo
# Country : Kagoshima
# capital : Paris
# Country :
# capital : Szczecin
# Country :
# capital : Washington,_D.C.
# Country :
# capital : Sucre
# Country : Toulouse
# capital : Santiago
# Country :
# capital : Budapest
# Country :
# capital : Kinshasa
# Country :
# capital : Ottawa
# Country :
# capital : Budapest
# Country :
# capital : Berlin
# Country : Limoges
# capital : List_of_historical_capitals_of_Hungary
# Country : Republic_of_China_(1912–49)
# capital : Budapest
# Country : Canada
# capital : Berlin
# Country : Augsburg
# capital : Berlin
# Country : Telšiai
# capital : Kiev
# Country :
# capital : Washington,_D.C.
# Country : Pest,_Hungary
# capital : Washington,_D.C.
# Country : Chiba_Prefecture
# capital : Tunis
# Country :
# capital : Budapest
# Country : Lingenfeld
# capital : Hanoi
# Country : Fürstenwalde
# capital : Moscow
# Country :
# capital : Tokyo
# Country : Tübingen
# capital : Magdeburg
# Country : Bregenz
# capital : Tehran
# Country :
# capital : Warsaw
# Country : Vienna
# capital : Antananarivo
# Country : France
# capital : Xuzhou
# Country :
# capital : Bern
# Country : France
# capital : Amsterdam
# Country : Italy
# capital : Berlin
# Country : Amsterdam
# capital : Seoul
# Country :
# capital : Vilnius
# Country : Momignies
# capital : Almaty
# Country :
# capital : Athens
# Country : Kohtla-Järve
# capital : Berlin
# Country : Boise,_Idaho
# capital : Washington,_D.C.
# Country : Madrid
# capital : Tokyo
# Country : Tulsa,_Oklahoma
# capital : Tokyo
# Country : English_cricket_team

# %% [markdown]
# ## changing the value of the column in the dataframe and save it into a .csv file

# %%
data["birthcountry"] = birthcountry_clean

# %%
data.to_csv("Suicide_withDBPedia_Values_fr.csv",index=False, sep=",", encoding='utf-8-sig')
