# %%
import pandas as pd

# %%
data = pd.read_csv("../data/Suicides_wikipedia_scrapping_fr_LEMMATISER_AND_TAGS2.csv", sep=";")
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                    Name  \
# 0           0             0            Adolfo_Couve
# 1           1             1               Boaz_Arad
# 2           2             2            Ralph_Barton
# 3           3             3             Mark_Campos
# 4           4             4  Michel_Caron_(artiste)
#
#                                                 Link  \
# 0         https://fr.wikipedia.org/wiki/Adolfo_Couve
# 1            https://fr.wikipedia.org/wiki/Boaz_Arad
# 2         https://fr.wikipedia.org/wiki/Ralph_Barton
# 3          https://fr.wikipedia.org/wiki/Mark_Campos
# 4  https://fr.wikipedia.org/wiki/Michel_Caron_(ar...
#
#                                              Content  \
# 0  ['Fils', 'd', 'Adolfo', 'Couve', 'Braga', 'et'...
# 1  ['Carrière', 'artistique', 'Artiste', 'multidi...
# 2  ['Originaire', 'de', 'Kansas', 'City', 'Missou...
# 3  ['Cette', 'section', 'est', 'vide', 'insuffisa...
# 4  ['Dès', 'l’enfance', 'Michel', 'Caron', 'veut'...
#
# ...

# %%
list_of_biography = []
for row in data:
    if row != "['[]']":
        list_of_biography.append(eval(row))
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\mateg\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-88-3dc380676c4b>", line 4, in <module>
#     list_of_biography.append(eval(row))
#
#   File "<string>", line 1
#     Unnamed: 0
#            ^
# SyntaxError: invalid syntax

# %%
data_with_deathdate = pd.read_csv("../data/Suicide_withDBPedia_Values_fr.csv", sep=";")
data_with_deathdate = data_with_deathdate[["deathdate", "Name"]]
data_with_deathdate.head()
# Out:
#     deathdate            Name
# 0   1998-3-11    Adolfo_Couve
# 1   1931-5-19    Ralph_Barton
# 2   2003-3-14  Jack_Goldstein
# 3  1968-03-19   Paul_Markwitz
# 4  1941-03-28  Virginia_Woolf

# %%
persons_died_after_1900 = []
for i in range(len(data_with_deathdate["deathdate"])):
    try:
        deathdate = int(data_with_deathdate["deathdate"][i].split("-")[0])
        if deathdate >= 1900:
            persons_died_after_1900.append(data_with_deathdate["Name"][i])
    except ValueError:
        pass

# %%
len(persons_died_after_1900)
# Out:
# 987

# %%
data[data['Name'].isin(persons_died_after_1900)]
# Out:
#       Unnamed: 0  Unnamed: 0.1              Name  \
# 0              0             0      Adolfo_Couve
# 2              2             2      Ralph_Barton
# 8              8             8    Jack_Goldstein
# 11            11            11     Paul_Markwitz
# 13            13            13    Virginia_Woolf
# ...          ...           ...               ...
# 2015        2015          2015       Qiu_Miaojin
# 2017        2017          2017    Charles_Rocket
# 2023        2023          2023  Hidemitsu_Tanaka
# 2048        2048          2048   Chujiro_Hayashi
# 2073        2073          2073    Emilio_Salgari
#
#                                                 Link  \
# 0         https://fr.wikipedia.org/wiki/Adolfo_Couve
# 2         https://fr.wikipedia.org/wiki/Ralph_Barton
# 8       https://fr.wikipedia.org/wiki/Jack_Goldstein
# 11       https://fr.wikipedia.org/wiki/Paul_Markwitz
# 13      https://fr.wikipedia.org/wiki/Virginia_Woolf
# ...
